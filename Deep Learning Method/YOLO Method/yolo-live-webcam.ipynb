# %%
from ultralytics import YOLO
import cv2
import math
import os
import numpy as np

# Start webcam
cap = cv2.VideoCapture(0)
cap.set(3, 1280)
cap.set(4, 720)

# Load model
PATH = os.path.join(os.getcwd(), "colab notebook yolov8", "runs", "detect", "train2", "weights", "last.pt")
# PATH = os.path.join(os.getcwd(),  "colab notebook yolov11", "runs", "detect", "train", "weights", "best.pt")
# PATH = "yolo11m.pt"
print(PATH)

model = YOLO(PATH)

# Object classes
classNames = ['Cardboard', 'Glass', 'Metal', 'Paper', 'Plastic', 'Trash']

while True:
    success, img = cap.read()
    if not success:
        break

    results = model(img, stream=True)

    # Process results
    for r in results:
        boxes = r.boxes

        for box in boxes:
            if box is None:
                continue
            # Bounding box coordinates
            x1, y1, x2, y2 = box.xyxy[0].numpy()
            print("Bounding box coordinates -->", x1, y1, x2, y2)
            if any(map(np.isnan, [x1, y1, x2, y2])):  # Check for NaN values
                print("Invalid bounding box coordinates detected.")
                continue  # Skip this box
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)  # Convert to int values

            # Draw bounding box on image
            cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 3)

            # Confidence
            confidence = box.conf[0].cpu().numpy()
            confidence = math.ceil((confidence * 100)) / 100
            print("Confidence --->", confidence)

            # Class name
            cls = int(box.cls[0].cpu().numpy())
            # print("Class name -->", cls)
            print("Class name -->", classNames[cls])

            # Object details
            org = (x1, y1)
            font = cv2.FONT_HERSHEY_SIMPLEX
            fontScale = 1
            color = (255, 0, 0)
            thickness = 2

            cv2.putText(img, f"{classNames[cls]} {confidence}", org, font, fontScale, color, thickness)

    cv2.imshow('Webcam', img)
    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# c:\Users\tyogo\OneDrive - Bina Nusantara\Semester 5\COMP_Computer Vision\Final Project\colab notebook yolov8\runs\detect\train2\weights\last.pt
#
# 0: 160x256 (no detections), 400.2ms
# Speed: 21.8ms preprocess, 400.2ms inference, 13.6ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 132.7ms
# Speed: 2.0ms preprocess, 132.7ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 135.9ms
# Speed: 1.1ms preprocess, 135.9ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 102.9ms
# Speed: 2.1ms preprocess, 102.9ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 138.5ms
# Speed: 1.6ms preprocess, 138.5ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 213.4ms
# Speed: 1.1ms preprocess, 213.4ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 150.4ms
# Speed: 2.5ms preprocess, 150.4ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 111.2ms
# Speed: 3.0ms preprocess, 111.2ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 103.2ms
# Speed: 1.9ms preprocess, 103.2ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 116.7ms
# Speed: 2.0ms preprocess, 116.7ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 109.7ms
# Speed: 2.0ms preprocess, 109.7ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 plastic, 106.2ms
# Bounding box coordinates --> 307.07538 101.92978 1278.343 718.5196
# Confidence ---> 0.35
# Class name --> Plastic
# Speed: 1.0ms preprocess, 106.2ms inference, 16.2ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 102.1ms
# Speed: 2.0ms preprocess, 102.1ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 104.2ms
# Speed: 1.0ms preprocess, 104.2ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 103.3ms
# Speed: 2.0ms preprocess, 103.3ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 86.8ms
# Speed: 1.0ms preprocess, 86.8ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 88.9ms
# Speed: 1.0ms preprocess, 88.9ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 84.8ms
# Speed: 1.0ms preprocess, 84.8ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 84.3ms
# Speed: 0.5ms preprocess, 84.3ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 organic, 85.3ms
# Bounding box coordinates --> 528.799 131.60156 789.29425 500.27502
# Confidence ---> 0.29
# Class name --> Metal
# Speed: 0.0ms preprocess, 85.3ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 organic, 87.0ms
# Bounding box coordinates --> 526.3671 133.4629 790.3119 500.0289
# Confidence ---> 0.37
# Class name --> Metal
# Speed: 1.0ms preprocess, 87.0ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 organic, 87.8ms
# Bounding box coordinates --> 521.2303 132.10983 786.5994 499.9787
# Confidence ---> 0.35
# Class name --> Metal
# Speed: 1.0ms preprocess, 87.8ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 organic, 86.5ms
# Bounding box coordinates --> 508.3051 119.22508 795.40594 502.67563
# Confidence ---> 0.39
# Class name --> Metal
# Speed: 1.0ms preprocess, 86.5ms inference, 2.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 organic, 85.3ms
# Bounding box coordinates --> 515.5735 121.361084 800.96075 504.96902
# Confidence ---> 0.65
# Class name --> Metal
# Speed: 1.0ms preprocess, 85.3ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 100.5ms
# Speed: 2.5ms preprocess, 100.5ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 87.2ms
# Speed: 1.1ms preprocess, 87.2ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 organic, 100.9ms
# Bounding box coordinates --> 521.8083 120.47283 808.14374 505.64694
# Confidence ---> 0.43
# Class name --> Metal
# Speed: 1.5ms preprocess, 100.9ms inference, 2.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 organic, 105.1ms
# Bounding box coordinates --> 518.62836 120.691376 803.70056 504.78943
# Confidence ---> 0.51
# Class name --> Metal
# Speed: 1.5ms preprocess, 105.1ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 organic, 102.5ms
# Bounding box coordinates --> 525.1853 118.63687 808.7356 505.30066
# Confidence ---> 0.26
# Class name --> Metal
# Speed: 1.0ms preprocess, 102.5ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 103.3ms
# Speed: 1.0ms preprocess, 103.3ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 100.1ms
# Speed: 2.0ms preprocess, 100.1ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 106.4ms
# Speed: 1.0ms preprocess, 106.4ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 90.2ms
# Speed: 1.0ms preprocess, 90.2ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 99.3ms
# Speed: 1.0ms preprocess, 99.3ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 93.4ms
# Speed: 1.0ms preprocess, 93.4ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 88.4ms
# Speed: 1.5ms preprocess, 88.4ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 88.5ms
# Speed: 2.0ms preprocess, 88.5ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 organic, 87.6ms
# Bounding box coordinates --> 523.6418 114.14604 858.29297 513.6667
# Confidence ---> 0.29
# Class name --> Metal
# Speed: 1.0ms preprocess, 87.6ms inference, 2.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 80.3ms
# Speed: 1.0ms preprocess, 80.3ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 plastic, 82.8ms
# Bounding box coordinates --> 297.7471 103.96711 1268.8066 717.894
# Confidence ---> 0.62
# Class name --> Plastic
# Speed: 1.0ms preprocess, 82.8ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 87.7ms
# Speed: 0.5ms preprocess, 87.7ms inference, 1.6ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 86.3ms
# Speed: 1.0ms preprocess, 86.3ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 83.7ms
# Speed: 1.0ms preprocess, 83.7ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 92.4ms
# Speed: 3.0ms preprocess, 92.4ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 89.5ms
# Speed: 1.0ms preprocess, 89.5ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 89.9ms
# Speed: 1.0ms preprocess, 89.9ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 91.8ms
# Speed: 1.0ms preprocess, 91.8ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 91.4ms
# Speed: 1.0ms preprocess, 91.4ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 87.8ms
# Speed: 1.0ms preprocess, 87.8ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 83.7ms
# Speed: 1.6ms preprocess, 83.7ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 84.8ms
# Speed: 1.0ms preprocess, 84.8ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 77.8ms
# Speed: 1.0ms preprocess, 77.8ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 80.9ms
# Speed: 1.0ms preprocess, 80.9ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 84.7ms
# Speed: 1.0ms preprocess, 84.7ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 90.0ms
# Speed: 1.0ms preprocess, 90.0ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 90.8ms
# Speed: 1.0ms preprocess, 90.8ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 93.3ms
# Speed: 2.0ms preprocess, 93.3ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 94.3ms
# Speed: 1.0ms preprocess, 94.3ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 97.3ms
# Speed: 1.0ms preprocess, 97.3ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 95.3ms
# Speed: 1.0ms preprocess, 95.3ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 91.4ms
# Speed: 1.0ms preprocess, 91.4ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 82.8ms
# Speed: 1.0ms preprocess, 82.8ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 89.9ms
# Speed: 2.0ms preprocess, 89.9ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 89.7ms
# Speed: 1.0ms preprocess, 89.7ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 127.8ms
# Speed: 1.0ms preprocess, 127.8ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 82.3ms
# Speed: 1.0ms preprocess, 82.3ms inference, 1.6ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 80.8ms
# Speed: 1.0ms preprocess, 80.8ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 91.4ms
# Speed: 1.0ms preprocess, 91.4ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 plastic, 74.7ms
# Bounding box coordinates --> 1.6999435 392.1515 488.03683 718.65424
# Confidence ---> 0.57
# Class name --> Plastic
# Speed: 2.0ms preprocess, 74.7ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 plastic, 84.5ms
# Bounding box coordinates --> 1.6999435 392.1515 488.03683 718.65424
# Confidence ---> 0.57
# Class name --> Plastic
# Speed: 1.0ms preprocess, 84.5ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 plastic, 97.9ms
# Bounding box coordinates --> 1.6181564 387.1865 494.64093 718.725
# Confidence ---> 0.61
# Class name --> Plastic
# Speed: 2.1ms preprocess, 97.9ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 plastic, 95.4ms
# Bounding box coordinates --> 1.5938187 389.7618 496.4304 718.7104
# Confidence ---> 0.59
# Class name --> Plastic
# Speed: 0.5ms preprocess, 95.4ms inference, 1.6ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 plastic, 86.5ms
# Bounding box coordinates --> 0.7936096 391.43896 474.2975 719.8809
# Confidence ---> 0.29
# Class name --> Plastic
# Speed: 1.1ms preprocess, 86.5ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 plastic, 86.4ms
# Bounding box coordinates --> 0.7936096 391.43896 474.2975 719.8809
# Confidence ---> 0.29
# Class name --> Plastic
# Speed: 1.0ms preprocess, 86.4ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 plastic, 87.8ms
# Bounding box coordinates --> 0.75798035 390.74316 478.71298 719.8227
# Confidence ---> 0.4
# Class name --> Plastic
# Speed: 0.0ms preprocess, 87.8ms inference, 2.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 plastic, 98.0ms
# Bounding box coordinates --> 0.7888794 392.54523 479.03494 719.8285
# Confidence ---> 0.47
# Class name --> Plastic
# Speed: 1.0ms preprocess, 98.0ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 plastic, 78.7ms
# Bounding box coordinates --> 0.6460953 392.28867 478.94107 719.72253
# Confidence ---> 0.34
# Class name --> Plastic
# Speed: 1.0ms preprocess, 78.7ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 81.7ms
# Speed: 1.0ms preprocess, 81.7ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 77.8ms
# Speed: 2.0ms preprocess, 77.8ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 plastic, 87.9ms
# Bounding box coordinates --> 0.6673813 393.0152 482.0857 719.7629
# Confidence ---> 0.46
# Class name --> Plastic
# Speed: 2.0ms preprocess, 87.9ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 plastic, 81.8ms
# Bounding box coordinates --> 0.70961 391.7835 482.96118 719.66034
# Confidence ---> 0.53
# Class name --> Plastic
# Speed: 1.0ms preprocess, 81.8ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 85.4ms
# Speed: 1.0ms preprocess, 85.4ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 plastic, 83.6ms
# Bounding box coordinates --> 0.5501938 393.3281 478.83832 719.658
# Confidence ---> 0.36
# Class name --> Plastic
# Speed: 1.0ms preprocess, 83.6ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 plastic, 80.7ms
# Bounding box coordinates --> 0.5731201 392.1495 483.0943 719.83014
# Confidence ---> 0.27
# Class name --> Plastic
# Speed: 1.0ms preprocess, 80.7ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 plastic, 79.5ms
# Bounding box coordinates --> 0.5228424 392.6975 482.88382 719.8511
# Confidence ---> 0.36
# Class name --> Plastic
# Speed: 1.0ms preprocess, 79.5ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 plastic, 85.6ms
# Bounding box coordinates --> 0.64193726 392.52524 485.30594 719.79803
# Confidence ---> 0.31
# Class name --> Plastic
# Speed: 1.0ms preprocess, 85.6ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 plastic, 85.3ms
# Bounding box coordinates --> 0.6233978 392.04947 481.9448 719.9107
# Confidence ---> 0.4
# Class name --> Plastic
# Speed: 1.0ms preprocess, 85.3ms inference, 2.5ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 plastic, 90.9ms
# Bounding box coordinates --> 0.6769943 393.02878 486.7055 719.75323
# Confidence ---> 0.62
# Class name --> Plastic
# Speed: 2.0ms preprocess, 90.9ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 organic, 1 plastic, 88.7ms
# Bounding box coordinates --> 0.7358551 391.2622 483.62057 719.7031
# Confidence ---> 0.43
# Class name --> Plastic
# Bounding box coordinates --> 524.10706 137.55267 788.7979 529.10455
# Confidence ---> 0.28
# Class name --> Metal
# Speed: 2.0ms preprocess, 88.7ms inference, 7.8ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 plastic, 90.8ms
# Bounding box coordinates --> 1.4638519 389.51538 503.1198 718.5714
# Confidence ---> 0.41
# Class name --> Plastic
# Speed: 1.0ms preprocess, 90.8ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 plastic, 88.6ms
# Bounding box coordinates --> 1.3645554 385.26938 500.12402 718.56604
# Confidence ---> 0.47
# Class name --> Plastic
# Speed: 1.5ms preprocess, 88.6ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 plastic, 93.4ms
# Bounding box coordinates --> 350.71426 98.18153 1280.0 717.43866
# Confidence ---> 0.28
# Class name --> Plastic
# Speed: 2.0ms preprocess, 93.4ms inference, 2.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 2 organics, 1 plastic, 87.4ms
# Bounding box coordinates --> 1069.7655 547.36896 1267.8643 719.48926
# Confidence ---> 0.51
# Class name --> Metal
# Bounding box coordinates --> 1044.3379 323.11905 1280.0 506.2329
# Confidence ---> 0.35
# Class name --> Metal
# Bounding box coordinates --> 383.76343 63.32611 1274.7402 715.5601
# Confidence ---> 0.31
# Class name --> Plastic
# Speed: 1.0ms preprocess, 87.4ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 plastic, 91.8ms
# Bounding box coordinates --> 467.63846 65.02617 1276.4038 694.9057
# Confidence ---> 0.38
# Class name --> Plastic
# Speed: 1.6ms preprocess, 91.8ms inference, 1.6ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 organic, 84.3ms
# Bounding box coordinates --> 657.56464 110.66826 942.60706 500.10696
# Confidence ---> 0.61
# Class name --> Metal
# Speed: 1.1ms preprocess, 84.3ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 89.0ms
# Speed: 1.1ms preprocess, 89.0ms inference, 0.6ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 organic, 93.0ms
# Bounding box coordinates --> 661.6873 121.208916 955.4288 512.82654
# Confidence ---> 0.67
# Class name --> Metal
# Speed: 0.0ms preprocess, 93.0ms inference, 0.8ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 organic, 91.6ms
# Bounding box coordinates --> 666.4679 124.1082 941.8353 523.86597
# Confidence ---> 0.59
# Class name --> Metal
# Speed: 2.0ms preprocess, 91.6ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 organic, 81.8ms
# Bounding box coordinates --> 673.834 125.576324 944.775 530.3632
# Confidence ---> 0.43
# Class name --> Metal
# Speed: 2.0ms preprocess, 81.8ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 organic, 80.3ms
# Bounding box coordinates --> 652.68616 124.96301 940.3003 510.27167
# Confidence ---> 0.46
# Class name --> Metal
# Speed: 2.0ms preprocess, 80.3ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 81.9ms
# Speed: 1.0ms preprocess, 81.9ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 85.0ms
# Speed: 0.0ms preprocess, 85.0ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 organic, 81.3ms
# Bounding box coordinates --> 675.5676 74.06288 897.5978 324.77585
# Confidence ---> 0.58
# Class name --> Metal
# Speed: 1.0ms preprocess, 81.3ms inference, 2.5ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 organic, 81.6ms
# Bounding box coordinates --> 672.9222 6.1674595 898.089 321.72125
# Confidence ---> 0.61
# Class name --> Metal
# Speed: 1.0ms preprocess, 81.6ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 2 organics, 80.8ms
# Bounding box coordinates --> 664.9292 5.01503 935.89935 366.14874
# Confidence ---> 0.85
# Class name --> Metal
# Bounding box coordinates --> 860.9196 190.73189 1092.3119 567.47046
# Confidence ---> 0.58
# Class name --> Metal
# Speed: 1.0ms preprocess, 80.8ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 86.2ms
# Speed: 0.0ms preprocess, 86.2ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 organic, 1 plastic, 83.1ms
# Bounding box coordinates --> 606.7667 125.65689 953.6295 538.5961
# Confidence ---> 0.78
# Class name --> Metal
# Bounding box coordinates --> 0.046691895 384.1307 690.6697 718.6914
# Confidence ---> 0.57
# Class name --> Plastic
# Speed: 1.0ms preprocess, 83.1ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 organic, 1 plastic, 91.4ms
# Bounding box coordinates --> 606.3013 119.98844 1017.4515 573.3541
# Confidence ---> 0.79
# Class name --> Metal
# Bounding box coordinates --> 1.4042664 391.34177 537.60284 719.631
# Confidence ---> 0.6
# Class name --> Plastic
# Speed: 1.5ms preprocess, 91.4ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 plastic, 77.5ms
# Bounding box coordinates --> 0.18726349 382.2483 524.6635 719.29315
# Confidence ---> 0.29
# Class name --> Plastic
# Speed: 1.0ms preprocess, 77.5ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 organic, 84.9ms
# Bounding box coordinates --> 544.31604 163.12544 987.17316 648.30383
# Confidence ---> 0.76
# Class name --> Metal
# Speed: 1.0ms preprocess, 84.9ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 plastic, 80.3ms
# Bounding box coordinates --> 503.0783 82.81174 1272.7681 718.5253
# Confidence ---> 0.42
# Class name --> Plastic
# Speed: 1.0ms preprocess, 80.3ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 78.6ms
# Speed: 1.0ms preprocess, 78.6ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 84.7ms
# Speed: 0.0ms preprocess, 84.7ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 2 organics, 81.4ms
# Bounding box coordinates --> 564.9002 324.32404 837.9707 659.987
# Confidence ---> 0.28
# Class name --> Metal
# Bounding box coordinates --> 678.46436 268.45383 871.64856 459.47302
# Confidence ---> 0.28
# Class name --> Metal
# Speed: 1.0ms preprocess, 81.4ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 2 organics, 80.3ms
# Bounding box coordinates --> 564.9002 324.32404 837.9707 659.987
# Confidence ---> 0.28
# Class name --> Metal
# Bounding box coordinates --> 678.46436 268.45383 871.64856 459.47302
# Confidence ---> 0.28
# Class name --> Metal
# Speed: 2.0ms preprocess, 80.3ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 2 organics, 79.7ms
# Bounding box coordinates --> 569.1966 313.4088 963.40344 644.447
# Confidence ---> 0.35
# Class name --> Metal
# Bounding box coordinates --> 1050.827 248.6055 1279.7936 562.0202
# Confidence ---> 0.27
# Class name --> Metal
# Speed: 1.5ms preprocess, 79.7ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 organic, 78.2ms
# Bounding box coordinates --> 543.47217 0.0 910.45514 373.9849
# Confidence ---> 0.26
# Class name --> Metal
# Speed: 1.0ms preprocess, 78.2ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 89.2ms
# Speed: 1.0ms preprocess, 89.2ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 79.5ms
# Speed: 1.2ms preprocess, 79.5ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 80.8ms
# Speed: 1.1ms preprocess, 80.8ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 79.8ms
# Speed: 0.5ms preprocess, 79.8ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 77.3ms
# Speed: 1.0ms preprocess, 77.3ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 81.9ms
# Speed: 1.0ms preprocess, 81.9ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 80.5ms
# Speed: 1.0ms preprocess, 80.5ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 81.7ms
# Speed: 2.0ms preprocess, 81.7ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 90.1ms
# Speed: 1.0ms preprocess, 90.1ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 82.8ms
# Speed: 2.0ms preprocess, 82.8ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 organic, 78.7ms
# Bounding box coordinates --> 160.26276 0.0 1280.0 717.6698
# Confidence ---> 0.54
# Class name --> Metal
# Speed: 1.0ms preprocess, 78.7ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 organic, 77.3ms
# Bounding box coordinates --> 7.2517395 2.2642517 1280.0 720.0
# Confidence ---> 0.8
# Class name --> Metal
# Speed: 1.0ms preprocess, 77.3ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 78.2ms
# Bounding box coordinates --> 6.398468 1.3370514 1280.0 720.0
# Confidence ---> 0.69
# Class name --> Paper
# Speed: 1.0ms preprocess, 78.2ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 1 plastic, 79.2ms
# Bounding box coordinates --> 63.3704 0.0 1280.0 718.25684
# Confidence ---> 0.75
# Class name --> Paper
# Bounding box coordinates --> 0.0 0.0 1278.9462 717.56525
# Confidence ---> 0.33
# Class name --> Plastic
# Speed: 1.0ms preprocess, 79.2ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 83.4ms
# Bounding box coordinates --> 65.09167 0.0 1279.5015 718.98926
# Confidence ---> 0.87
# Class name --> Paper
# Speed: 1.5ms preprocess, 83.4ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 84.1ms
# Bounding box coordinates --> 73.2222 0.0 1280.0 719.65985
# Confidence ---> 0.37
# Class name --> Paper
# Speed: 1.0ms preprocess, 84.1ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 92.4ms
# Speed: 1.0ms preprocess, 92.4ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 trash, 82.8ms
# Bounding box coordinates --> 1.1027527 0.3390503 1280.0 717.545
# Confidence ---> 0.4
# Class name --> Trash
# Speed: 1.0ms preprocess, 82.8ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 1 plastic, 80.1ms
# Bounding box coordinates --> 59.0691 0.0 1278.2799 716.9159
# Confidence ---> 0.29
# Class name --> Plastic
# Bounding box coordinates --> 2.5857544 0.53115845 1270.158 718.8783
# Confidence ---> 0.28
# Class name --> Paper
# Speed: 1.0ms preprocess, 80.1ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 82.3ms
# Speed: 1.0ms preprocess, 82.3ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 83.3ms
# Bounding box coordinates --> 31.065063 0.0 1280.0 717.3971
# Confidence ---> 0.33
# Class name --> Paper
# Speed: 2.0ms preprocess, 83.3ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 81.7ms
# Bounding box coordinates --> 5.553131 0.0 1278.1426 717.81384
# Confidence ---> 0.43
# Class name --> Paper
# Speed: 2.0ms preprocess, 81.7ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 81.2ms
# Speed: 0.5ms preprocess, 81.2ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 80.8ms
# Speed: 1.0ms preprocess, 80.8ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 78.3ms
# Speed: 1.0ms preprocess, 78.3ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 trash, 81.8ms
# Bounding box coordinates --> 955.1056 376.38327 1280.0 581.46704
# Confidence ---> 0.74
# Class name --> Trash
# Speed: 2.0ms preprocess, 81.8ms inference, 2.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 trash, 83.0ms
# Bounding box coordinates --> 992.74475 381.03827 1279.7289 584.22064
# Confidence ---> 0.29
# Class name --> Trash
# Speed: 0.5ms preprocess, 83.0ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 2 trashs, 82.3ms
# Bounding box coordinates --> 990.9665 241.92412 1280.0 568.3287
# Confidence ---> 0.69
# Class name --> Trash
# Bounding box coordinates --> 997.5819 355.9839 1280.0 564.84406
# Confidence ---> 0.3
# Class name --> Trash
# Speed: 1.1ms preprocess, 82.3ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 83.1ms
# Speed: 1.0ms preprocess, 83.1ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 85.2ms
# Speed: 1.0ms preprocess, 85.2ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 85.8ms
# Speed: 2.0ms preprocess, 85.8ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 84.8ms
# Speed: 1.5ms preprocess, 84.8ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 84.3ms
# Speed: 1.0ms preprocess, 84.3ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 organic, 86.9ms
# Bounding box coordinates --> 797.5468 0.27921677 1280.0 583.136
# Confidence ---> 0.46
# Class name --> Metal
# Speed: 1.0ms preprocess, 86.9ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 84.3ms
# Speed: 1.0ms preprocess, 84.3ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 79.7ms
# Speed: 1.0ms preprocess, 79.7ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 85.9ms
# Speed: 2.0ms preprocess, 85.9ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 81.8ms
# Speed: 1.0ms preprocess, 81.8ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 83.6ms
# Speed: 2.0ms preprocess, 83.6ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 85.3ms
# Speed: 1.0ms preprocess, 85.3ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 plastic, 86.0ms
# Bounding box coordinates --> 6.5454865 0.0 1278.4929 719.6669
# Confidence ---> 0.94
# Class name --> Plastic
# Speed: 2.0ms preprocess, 86.0ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 plastic, 86.7ms
# Bounding box coordinates --> 63.269806 53.87787 1280.0 719.55725
# Confidence ---> 0.81
# Class name --> Plastic
# Speed: 1.0ms preprocess, 86.7ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 87.1ms
# Bounding box coordinates --> 2.728119 90.72487 1279.9502 719.40076
# Confidence ---> 0.44
# Class name --> Paper
# Speed: 1.0ms preprocess, 87.1ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 90.8ms
# Speed: 0.0ms preprocess, 90.8ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 99.4ms
# Speed: 1.0ms preprocess, 99.4ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 plastic, 86.5ms
# Bounding box coordinates --> 2.9628372 0.7168579 1280.0 720.0
# Confidence ---> 0.72
# Class name --> Plastic
# Speed: 0.0ms preprocess, 86.5ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 2 plastics, 98.9ms
# Bounding box coordinates --> 10.678558 1.2317657 1280.0 720.0
# Confidence ---> 0.54
# Class name --> Plastic
# Bounding box coordinates --> 86.10378 525.3482 245.97385 718.7471
# Confidence ---> 0.28
# Class name --> Plastic
# Speed: 1.0ms preprocess, 98.9ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 83.3ms
# Bounding box coordinates --> 1.000061 12.6931 1274.8824 720.0
# Confidence ---> 0.33
# Class name --> Paper
# Speed: 1.0ms preprocess, 83.3ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 93.5ms
# Bounding box coordinates --> 1.000061 12.6931 1274.8824 720.0
# Confidence ---> 0.33
# Class name --> Paper
# Speed: 0.0ms preprocess, 93.5ms inference, 1.2ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 87.2ms
# Bounding box coordinates --> 2.41539 5.068054 1275.2605 720.0
# Confidence ---> 0.57
# Class name --> Paper
# Speed: 1.0ms preprocess, 87.2ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 82.3ms
# Speed: 1.1ms preprocess, 82.3ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 84.9ms
# Speed: 2.0ms preprocess, 84.9ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 96.9ms
# Speed: 1.0ms preprocess, 96.9ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 plastic, 90.8ms
# Bounding box coordinates --> 0.8395386 0.0 1278.2125 720.0
# Confidence ---> 0.88
# Class name --> Plastic
# Speed: 1.0ms preprocess, 90.8ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 plastic, 94.1ms
# Bounding box coordinates --> 0.79444885 0.0 1276.3738 720.0
# Confidence ---> 0.72
# Class name --> Plastic
# Speed: 1.0ms preprocess, 94.1ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 plastic, 87.9ms
# Bounding box coordinates --> 0.5742645 0.0 1257.4963 720.0
# Confidence ---> 0.59
# Class name --> Plastic
# Speed: 1.5ms preprocess, 87.9ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 plastic, 85.8ms
# Bounding box coordinates --> 0.10765076 0.17173767 1223.579 720.0
# Confidence ---> 0.43
# Class name --> Plastic
# Speed: 0.0ms preprocess, 85.8ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 81.0ms
# Speed: 0.0ms preprocess, 81.0ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 86.9ms
# Speed: 1.0ms preprocess, 86.9ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 81.3ms
# Speed: 1.0ms preprocess, 81.3ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 88.9ms
# Speed: 1.5ms preprocess, 88.9ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 85.8ms
# Bounding box coordinates --> 1.1831665 0.0 1275.3966 720.0
# Confidence ---> 0.65
# Class name --> Paper
# Speed: 1.0ms preprocess, 85.8ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 82.2ms
# Bounding box coordinates --> 0.9172058 0.0 1280.0 719.2328
# Confidence ---> 0.7
# Class name --> Paper
# Speed: 1.5ms preprocess, 82.2ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 83.5ms
# Bounding box coordinates --> 0.6515503 0.0 1280.0 720.0
# Confidence ---> 0.71
# Class name --> Paper
# Speed: 1.0ms preprocess, 83.5ms inference, 0.9ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 78.3ms
# Bounding box coordinates --> 0.6515503 0.0 1280.0 720.0
# Confidence ---> 0.71
# Class name --> Paper
# Speed: 1.0ms preprocess, 78.3ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 84.8ms
# Bounding box coordinates --> 0.08255005 0.0 1279.0687 720.0
# Confidence ---> 0.45
# Class name --> Paper
# Speed: 1.0ms preprocess, 84.8ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 87.2ms
# Bounding box coordinates --> 0.8258438 0.0 1280.0 720.0
# Confidence ---> 0.52
# Class name --> Paper
# Speed: 1.0ms preprocess, 87.2ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 85.6ms
# Bounding box coordinates --> 0.41885376 0.0 1279.4653 720.0
# Confidence ---> 0.35
# Class name --> Paper
# Speed: 2.5ms preprocess, 85.6ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 80.2ms
# Bounding box coordinates --> 0.7408905 0.0 1279.5114 720.0
# Confidence ---> 0.64
# Class name --> Paper
# Speed: 1.5ms preprocess, 80.2ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 76.7ms
# Bounding box coordinates --> 0.7408905 0.0 1279.5114 720.0
# Confidence ---> 0.64
# Class name --> Paper
# Speed: 2.0ms preprocess, 76.7ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 85.0ms
# Bounding box coordinates --> 0.22476196 0.0 1278.9845 720.0
# Confidence ---> 0.49
# Class name --> Paper
# Speed: 1.0ms preprocess, 85.0ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 89.9ms
# Bounding box coordinates --> 0.745697 0.0 1278.03 720.0
# Confidence ---> 0.6
# Class name --> Paper
# Speed: 1.0ms preprocess, 89.9ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 84.0ms
# Bounding box coordinates --> 0.97618103 0.0 1277.8558 720.0
# Confidence ---> 0.38
# Class name --> Paper
# Speed: 1.0ms preprocess, 84.0ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 79.7ms
# Bounding box coordinates --> 0.7410431 0.0 1278.7587 720.0
# Confidence ---> 0.52
# Class name --> Paper
# Speed: 1.5ms preprocess, 79.7ms inference, 2.4ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 82.6ms
# Bounding box coordinates --> 1.0437775 0.0 1279.7582 720.0
# Confidence ---> 0.58
# Class name --> Paper
# Speed: 1.1ms preprocess, 82.6ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 90.3ms
# Bounding box coordinates --> 1.0437775 0.0 1279.7582 720.0
# Confidence ---> 0.58
# Class name --> Paper
# Speed: 1.0ms preprocess, 90.3ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 78.8ms
# Bounding box coordinates --> 1.0079575 0.0 1280.0 719.90784
# Confidence ---> 0.47
# Class name --> Paper
# Speed: 1.0ms preprocess, 78.8ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 89.4ms
# Bounding box coordinates --> 0.8520508 0.0 1280.0 720.0
# Confidence ---> 0.34
# Class name --> Paper
# Speed: 1.0ms preprocess, 89.4ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 82.4ms
# Bounding box coordinates --> 0.39901733 0.0 1279.9675 719.63354
# Confidence ---> 0.42
# Class name --> Paper
# Speed: 1.0ms preprocess, 82.4ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 81.2ms
# Bounding box coordinates --> 0.785141 0.0 1279.9987 720.0
# Confidence ---> 0.34
# Class name --> Paper
# Speed: 1.0ms preprocess, 81.2ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 82.3ms
# Speed: 1.0ms preprocess, 82.3ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 82.6ms
# Bounding box coordinates --> 0.35942078 0.0 1279.2528 720.0
# Confidence ---> 0.62
# Class name --> Paper
# Speed: 0.0ms preprocess, 82.6ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 88.4ms
# Bounding box coordinates --> 0.64178467 0.0 1279.4497 720.0
# Confidence ---> 0.4
# Class name --> Paper
# Speed: 0.0ms preprocess, 88.4ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 84.3ms
# Bounding box coordinates --> 0.64178467 0.0 1279.4497 720.0
# Confidence ---> 0.4
# Class name --> Paper
# Speed: 0.0ms preprocess, 84.3ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 83.9ms
# Bounding box coordinates --> 1.2630844 0.0 1279.9518 720.0
# Confidence ---> 0.5
# Class name --> Paper
# Speed: 1.0ms preprocess, 83.9ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 90.8ms
# Bounding box coordinates --> 1.3028717 0.0 1278.0115 720.0
# Confidence ---> 0.56
# Class name --> Paper
# Speed: 0.0ms preprocess, 90.8ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 78.3ms
# Bounding box coordinates --> 0.99975586 0.0 1279.6884 720.0
# Confidence ---> 0.58
# Class name --> Paper
# Speed: 1.0ms preprocess, 78.3ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 83.8ms
# Bounding box coordinates --> 0.99975586 0.0 1279.6884 720.0
# Confidence ---> 0.58
# Class name --> Paper
# Speed: 1.0ms preprocess, 83.8ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 78.7ms
# Bounding box coordinates --> 1.9775391 0.0 1280.0 720.0
# Confidence ---> 0.39
# Class name --> Paper
# Speed: 1.0ms preprocess, 78.7ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 84.7ms
# Bounding box coordinates --> 1.8962097 0.0 1276.4281 720.0
# Confidence ---> 0.37
# Class name --> Paper
# Speed: 0.0ms preprocess, 84.7ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 81.7ms
# Bounding box coordinates --> 1.6036987 0.0 1274.9501 720.0
# Confidence ---> 0.56
# Class name --> Paper
# Speed: 0.0ms preprocess, 81.7ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 84.2ms
# Bounding box coordinates --> 1.6925812 0.0 1275.672 720.0
# Confidence ---> 0.39
# Class name --> Paper
# Speed: 1.0ms preprocess, 84.2ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 88.0ms
# Bounding box coordinates --> 1.6925812 0.0 1275.672 720.0
# Confidence ---> 0.39
# Class name --> Paper
# Speed: 1.0ms preprocess, 88.0ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 86.4ms
# Bounding box coordinates --> 1.6670227 0.0 1278.8445 720.0
# Confidence ---> 0.58
# Class name --> Paper
# Speed: 1.0ms preprocess, 86.4ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 86.4ms
# Bounding box coordinates --> 2.0486832 0.0 1280.0 720.0
# Confidence ---> 0.6
# Class name --> Paper
# Speed: 1.5ms preprocess, 86.4ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 83.8ms
# Bounding box coordinates --> 1.408844 0.0 1278.6929 720.0
# Confidence ---> 0.55
# Class name --> Paper
# Speed: 1.5ms preprocess, 83.8ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 90.4ms
# Bounding box coordinates --> 2.234497 0.0 1280.0 720.0
# Confidence ---> 0.72
# Class name --> Paper
# Speed: 1.1ms preprocess, 90.4ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 84.6ms
# Bounding box coordinates --> 0.9368515 0.0 1280.0 720.0
# Confidence ---> 0.82
# Class name --> Paper
# Speed: 0.0ms preprocess, 84.6ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 80.4ms
# Bounding box coordinates --> 0.9368515 0.0 1280.0 720.0
# Confidence ---> 0.82
# Class name --> Paper
# Speed: 1.1ms preprocess, 80.4ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 77.6ms
# Bounding box coordinates --> 0.9881592 0.0 1280.0 720.0
# Confidence ---> 0.76
# Class name --> Paper
# Speed: 1.0ms preprocess, 77.6ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 80.3ms
# Bounding box coordinates --> 4.3392944 0.0 1279.3016 720.0
# Confidence ---> 0.73
# Class name --> Paper
# Speed: 1.0ms preprocess, 80.3ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 81.6ms
# Bounding box coordinates --> 2.197609 0.0 1279.4277 720.0
# Confidence ---> 0.76
# Class name --> Paper
# Speed: 1.0ms preprocess, 81.6ms inference, 1.6ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 75.2ms
# Bounding box coordinates --> 4.396324 0.0 1279.7427 720.0
# Confidence ---> 0.72
# Class name --> Paper
# Speed: 1.0ms preprocess, 75.2ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 86.1ms
# Bounding box coordinates --> 4.396324 0.0 1279.7427 720.0
# Confidence ---> 0.72
# Class name --> Paper
# Speed: 1.0ms preprocess, 86.1ms inference, 1.6ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 81.5ms
# Bounding box coordinates --> 1.6082764 0.0 1280.0 720.0
# Confidence ---> 0.51
# Class name --> Paper
# Speed: 1.0ms preprocess, 81.5ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 81.3ms
# Bounding box coordinates --> 1.7699814 0.0 1279.4275 720.0
# Confidence ---> 0.54
# Class name --> Paper
# Speed: 2.5ms preprocess, 81.3ms inference, 2.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 83.2ms
# Bounding box coordinates --> 1.308136 0.0 1278.4835 720.0
# Confidence ---> 0.72
# Class name --> Paper
# Speed: 1.0ms preprocess, 83.2ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 80.8ms
# Bounding box coordinates --> 1.7240906 0.0 1279.6925 720.0
# Confidence ---> 0.75
# Class name --> Paper
# Speed: 1.0ms preprocess, 80.8ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 86.3ms
# Bounding box coordinates --> 1.7959595 0.0 1279.2859 720.0
# Confidence ---> 0.87
# Class name --> Paper
# Speed: 1.0ms preprocess, 86.3ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 83.8ms
# Bounding box coordinates --> 1.7959595 0.0 1279.2859 720.0
# Confidence ---> 0.87
# Class name --> Paper
# Speed: 1.0ms preprocess, 83.8ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 83.3ms
# Bounding box coordinates --> 2.422638 0.0 1280.0 720.0
# Confidence ---> 0.92
# Class name --> Paper
# Speed: 1.0ms preprocess, 83.3ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 87.3ms
# Bounding box coordinates --> 2.9071045 0.0 1280.0 720.0
# Confidence ---> 0.97
# Class name --> Paper
# Speed: 1.0ms preprocess, 87.3ms inference, 2.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 81.9ms
# Bounding box coordinates --> 2.2375488 0.0 1280.0 720.0
# Confidence ---> 0.98
# Class name --> Paper
# Speed: 1.0ms preprocess, 81.9ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 83.3ms
# Bounding box coordinates --> 1.9818115 0.0 1280.0 720.0
# Confidence ---> 0.98
# Class name --> Paper
# Speed: 1.0ms preprocess, 83.3ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 81.8ms
# Bounding box coordinates --> 1.3082504 0.0 1280.0 720.0
# Confidence ---> 0.97
# Class name --> Paper
# Speed: 1.0ms preprocess, 81.8ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 82.9ms
# Bounding box coordinates --> 1.2036514 0.0 1279.7046 720.0
# Confidence ---> 0.96
# Class name --> Paper
# Speed: 1.0ms preprocess, 82.9ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 85.1ms
# Bounding box coordinates --> 2.5815582 0.0 1279.8766 720.0
# Confidence ---> 0.98
# Class name --> Paper
# Speed: 2.5ms preprocess, 85.1ms inference, 2.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 84.2ms
# Bounding box coordinates --> 5.893173 0.0 1279.998 720.0
# Confidence ---> 0.97
# Class name --> Paper
# Speed: 1.5ms preprocess, 84.2ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 80.9ms
# Bounding box coordinates --> 5.893173 0.0 1279.998 720.0
# Confidence ---> 0.97
# Class name --> Paper
# Speed: 2.0ms preprocess, 80.9ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 74.9ms
# Bounding box coordinates --> 0.64682007 0.0 1280.0 720.0
# Confidence ---> 0.96
# Class name --> Paper
# Speed: 1.0ms preprocess, 74.9ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 120.3ms
# Bounding box coordinates --> 0.64682007 0.0 1280.0 720.0
# Confidence ---> 0.96
# Class name --> Paper
# Speed: 1.0ms preprocess, 120.3ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 84.8ms
# Bounding box coordinates --> 1.8991089 0.0 1280.0 720.0
# Confidence ---> 0.98
# Class name --> Paper
# Speed: 1.5ms preprocess, 84.8ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 79.6ms
# Bounding box coordinates --> 0.5474472 0.0 1280.0 720.0
# Confidence ---> 0.93
# Class name --> Paper
# Speed: 1.1ms preprocess, 79.6ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 79.3ms
# Bounding box coordinates --> 1.7292786 0.0 1279.923 720.0
# Confidence ---> 0.82
# Class name --> Paper
# Speed: 1.0ms preprocess, 79.3ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 78.3ms
# Bounding box coordinates --> 0.58258057 0.0 1279.9396 720.0
# Confidence ---> 0.8
# Class name --> Paper
# Speed: 2.0ms preprocess, 78.3ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 81.2ms
# Bounding box coordinates --> 1.867218 0.0 1279.7162 720.0
# Confidence ---> 0.69
# Class name --> Paper
# Speed: 1.0ms preprocess, 81.2ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 78.5ms
# Bounding box coordinates --> 1.7512131 0.0 1280.0 720.0
# Confidence ---> 0.6
# Class name --> Paper
# Speed: 2.0ms preprocess, 78.5ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 81.8ms
# ...
# Confidence ---> 0.74
# Class name --> Paper
# Speed: 1.0ms preprocess, 81.7ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 89.9ms
# Bounding box coordinates --> 4.927063 0.0 1280.0 718.043
# Confidence ---> 0.74
# Class name --> Paper
# Speed: 1.0ms preprocess, 89.9ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 87.4ms
# Speed: 1.0ms preprocess, 87.4ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 cigarette butt, 90.3ms
# Bounding box coordinates --> 736.03894 614.1922 986.5721 717.0535
# Confidence ---> 0.73
# Class name --> Cardboard
# Speed: 2.0ms preprocess, 90.3ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 organic, 86.2ms
# Bounding box coordinates --> 640.2429 189.45634 901.3519 523.33936
# Confidence ---> 0.36
# Class name --> Metal
# Speed: 1.0ms preprocess, 86.2ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 84.8ms
# Speed: 1.0ms preprocess, 84.8ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 89.7ms
# Speed: 1.0ms preprocess, 89.7ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 91.9ms
# Speed: 1.6ms preprocess, 91.9ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 90.3ms
# Bounding box coordinates --> 409.48685 91.64871 1280.0 717.103
# Confidence ---> 0.62
# Class name --> Paper
# Speed: 2.0ms preprocess, 90.3ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 plastic, 92.8ms
# Bounding box coordinates --> 567.83356 133.67227 961.5834 569.8685
# Confidence ---> 0.85
# Class name --> Plastic
# Speed: 1.6ms preprocess, 92.8ms inference, 2.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 91.1ms
# Speed: 1.0ms preprocess, 91.1ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 90.8ms
# Speed: 1.0ms preprocess, 90.8ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 87.4ms
# Speed: 1.5ms preprocess, 87.4ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 plastic, 82.9ms
# Bounding box coordinates --> 408.77838 101.53999 1066.123 718.76794
# Confidence ---> 0.91
# Class name --> Plastic
# Speed: 1.0ms preprocess, 82.9ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 plastic, 85.8ms
# Bounding box coordinates --> 408.77838 101.53999 1066.123 718.76794
# Confidence ---> 0.91
# Class name --> Plastic
# Speed: 5.0ms preprocess, 85.8ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 organic, 1 paper, 1 plastic, 83.8ms
# Bounding box coordinates --> 978.91187 537.5055 1280.0 720.0
# Confidence ---> 0.56
# Class name --> Metal
# Bounding box coordinates --> 338.0416 38.152542 1279.3955 720.0
# Confidence ---> 0.39
# Class name --> Paper
# Bounding box coordinates --> 342.9058 44.637375 1276.4929 720.0
# Confidence ---> 0.37
# Class name --> Plastic
# Speed: 1.0ms preprocess, 83.8ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 plastic, 89.1ms
# Bounding box coordinates --> 329.3839 26.523514 1278.3325 720.0
# Confidence ---> 0.32
# Class name --> Plastic
# Speed: 1.0ms preprocess, 89.1ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 organic, 89.3ms
# Bounding box coordinates --> 871.6548 509.3546 1278.3472 719.88776
# Confidence ---> 0.48
# Class name --> Metal
# Speed: 1.0ms preprocess, 89.3ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 89.0ms
# Speed: 0.0ms preprocess, 89.0ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 organic, 79.3ms
# Bounding box coordinates --> 821.47034 560.6056 1190.4694 718.2187
# Confidence ---> 0.35
# Class name --> Metal
# Speed: 1.0ms preprocess, 79.3ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 83.8ms
# Speed: 1.0ms preprocess, 83.8ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 organic, 85.6ms
# Bounding box coordinates --> 659.15265 222.07733 985.0778 619.15356
# Confidence ---> 0.55
# Class name --> Metal
# Speed: 1.0ms preprocess, 85.6ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 2 organics, 91.9ms
# Bounding box coordinates --> 669.8599 233.9164 980.7136 639.2148
# Confidence ---> 0.51
# Class name --> Metal
# Bounding box coordinates --> 801.1616 0.0 1016.5184 445.2951
# Confidence ---> 0.34
# Class name --> Metal
# Speed: 1.0ms preprocess, 91.9ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 organic, 78.8ms
# Bounding box coordinates --> 765.4117 337.87466 1133.3279 666.0147
# Confidence ---> 0.28
# Class name --> Metal
# Speed: 1.0ms preprocess, 78.8ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 organic, 87.4ms
# Bounding box coordinates --> 765.4117 337.87466 1133.3279 666.0147
# Confidence ---> 0.28
# Class name --> Metal
# Speed: 1.0ms preprocess, 87.4ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 organic, 82.6ms
# Bounding box coordinates --> 880.09216 218.42949 1272.2968 718.9921
# Confidence ---> 0.85
# Class name --> Metal
# Speed: 1.0ms preprocess, 82.6ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 organic, 1 paper, 86.0ms
# Bounding box coordinates --> 957.2061 431.7508 1265.5951 718.88776
# Confidence ---> 0.41
# Class name --> Metal
# Bounding box coordinates --> 1.3690186 0.0 1276.8312 718.20953
# Confidence ---> 0.37
# Class name --> Paper
# Speed: 1.0ms preprocess, 86.0ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 metal, 1 paper, 89.1ms
# Bounding box coordinates --> 0.0 0.0 1278.5706 718.46405
# Confidence ---> 0.77
# Class name --> Paper
# Bounding box coordinates --> 854.7438 303.9701 1280.0 720.0
# Confidence ---> 0.68
# Class name --> Glass
# Speed: 1.0ms preprocess, 89.1ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 metal, 1 plastic, 89.3ms
# Bounding box coordinates --> 821.5324 272.77005 1273.8527 720.0
# Confidence ---> 0.33
# Class name --> Glass
# Bounding box coordinates --> 820.8023 272.5215 1272.9833 720.0
# Confidence ---> 0.26
# Class name --> Plastic
# Speed: 1.0ms preprocess, 89.3ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 86.5ms
# Bounding box coordinates --> 743.65845 247.4932 1154.6249 683.1748
# Confidence ---> 0.29
# Class name --> Paper
# Speed: 0.5ms preprocess, 86.5ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 91.8ms
# Bounding box coordinates --> 743.65845 247.4932 1154.6249 683.1748
# Confidence ---> 0.29
# Class name --> Paper
# Speed: 1.0ms preprocess, 91.8ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 organic, 90.8ms
# Bounding box coordinates --> 785.9552 197.59196 1057.9877 512.1461
# Confidence ---> 0.54
# Class name --> Metal
# Speed: 1.1ms preprocess, 90.8ms inference, 1.6ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 organic, 97.2ms
# Bounding box coordinates --> 693.50037 114.94665 941.40576 449.20782
# Confidence ---> 0.68
# Class name --> Metal
# Speed: 1.1ms preprocess, 97.2ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 organic, 85.1ms
# Bounding box coordinates --> 735.03784 175.12086 1004.4864 503.94547
# Confidence ---> 0.28
# Class name --> Metal
# Speed: 1.0ms preprocess, 85.1ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 plastic, 81.2ms
# Bounding box coordinates --> 352.96237 97.917915 1280.0 719.499
# Confidence ---> 0.74
# Class name --> Plastic
# Speed: 1.0ms preprocess, 81.2ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 87.6ms
# Speed: 1.0ms preprocess, 87.6ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 79.5ms
# Speed: 2.0ms preprocess, 79.5ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 84.3ms
# Speed: 1.5ms preprocess, 84.3ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 2 organics, 81.3ms
# Bounding box coordinates --> 1032.8015 85.262184 1279.8864 486.42346
# Confidence ---> 0.83
# Class name --> Metal
# Bounding box coordinates --> 637.7759 490.7283 1088.536 716.3339
# Confidence ---> 0.39
# Class name --> Metal
# Speed: 2.0ms preprocess, 81.3ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 82.3ms
# Speed: 1.0ms preprocess, 82.3ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 78.8ms
# Bounding box coordinates --> 164.24484 2.0066833 1278.2092 720.0
# Confidence ---> 0.67
# Class name --> Paper
# Speed: 1.5ms preprocess, 78.8ms inference, 1.5ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 84.3ms
# Speed: 1.0ms preprocess, 84.3ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 83.3ms
# Speed: 1.0ms preprocess, 83.3ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 87.8ms
# Bounding box coordinates --> 145.0734 1.1651611 1278.13 720.0
# Confidence ---> 0.51
# Class name --> Paper
# Speed: 1.5ms preprocess, 87.8ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 organic, 79.3ms
# Bounding box coordinates --> 994.3617 78.563286 1280.0 489.05692
# Confidence ---> 0.61
# Class name --> Metal
# Speed: 1.0ms preprocess, 79.3ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 2 organics, 82.8ms
# Bounding box coordinates --> 949.50574 21.58207 1280.0 471.3113
# Confidence ---> 0.83
# Class name --> Metal
# Bounding box coordinates --> 577.72394 0.55191994 888.5102 266.8599
# Confidence ---> 0.7
# Class name --> Metal
# Speed: 1.0ms preprocess, 82.8ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 trash, 77.9ms
# Bounding box coordinates --> 500.5197 315.17844 952.6013 602.8567
# Confidence ---> 0.84
# Class name --> Trash
# Speed: 1.0ms preprocess, 77.9ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 91.3ms
# Speed: 2.5ms preprocess, 91.3ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 82.8ms
# Speed: 1.0ms preprocess, 82.8ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 106.5ms
# Speed: 1.0ms preprocess, 106.5ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 trash, 98.3ms
# Bounding box coordinates --> 478.99582 341.41165 942.5566 622.02057
# Confidence ---> 0.85
# Class name --> Trash
# Speed: 1.5ms preprocess, 98.3ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 trash, 115.0ms
# Bounding box coordinates --> 460.285 303.66196 966.0721 619.4116
# Confidence ---> 0.84
# Class name --> Trash
# Speed: 1.0ms preprocess, 115.0ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 160.7ms
# Speed: 1.6ms preprocess, 160.7ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 85.1ms
# Speed: 1.7ms preprocess, 85.1ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 96.5ms
# Speed: 1.0ms preprocess, 96.5ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 99.8ms
# Speed: 1.5ms preprocess, 99.8ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 85.3ms
# Speed: 1.0ms preprocess, 85.3ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 85.4ms
# Speed: 1.0ms preprocess, 85.4ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 89.7ms
# Bounding box coordinates --> 136.64226 0.0 1279.9183 716.04706
# Confidence ---> 0.31
# Class name --> Paper
# Speed: 1.0ms preprocess, 89.7ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 112.5ms
# Bounding box coordinates --> 136.64226 0.0 1279.9183 716.04706
# Confidence ---> 0.31
# Class name --> Paper
# Speed: 1.0ms preprocess, 112.5ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 125.6ms
# Bounding box coordinates --> 130.46008 0.0 1279.3586 718.02747
# Confidence ---> 0.49
# Class name --> Paper
# Speed: 2.0ms preprocess, 125.6ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 97.3ms
# Speed: 2.0ms preprocess, 97.3ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 90.9ms
# Bounding box coordinates --> 624.1156 0.0 1280.0 712.4313
# Confidence ---> 0.37
# Class name --> Paper
# Speed: 1.0ms preprocess, 90.9ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 84.9ms
# Bounding box coordinates --> 624.1156 0.0 1280.0 712.4313
# Confidence ---> 0.37
# Class name --> Paper
# Speed: 1.0ms preprocess, 84.9ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 plastic, 83.0ms
# Bounding box coordinates --> 619.4351 326.798 934.0042 680.1221
# Confidence ---> 0.26
# Class name --> Plastic
# Speed: 1.0ms preprocess, 83.0ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 109.7ms
# Speed: 1.4ms preprocess, 109.7ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 83.3ms
# Speed: 1.0ms preprocess, 83.3ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 paper, 88.8ms
# Bounding box coordinates --> 240.42377 0.0 1279.1423 710.50366
# Confidence ---> 0.3
# Class name --> Paper
# Speed: 1.0ms preprocess, 88.8ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 85.9ms
# Speed: 0.5ms preprocess, 85.9ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 90.7ms
# Speed: 1.0ms preprocess, 90.7ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 86.0ms
# Speed: 1.0ms preprocess, 86.0ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 87.3ms
# Speed: 0.5ms preprocess, 87.3ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 80.3ms
# Speed: 1.5ms preprocess, 80.3ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 87.2ms
# Speed: 1.0ms preprocess, 87.2ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 89.7ms
# Speed: 1.0ms preprocess, 89.7ms inference, 0.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 84.4ms
# Speed: 1.0ms preprocess, 84.4ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 90.3ms
# Speed: 2.0ms preprocess, 90.3ms inference, 1.1ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 86.9ms
# Speed: 1.1ms preprocess, 86.9ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 73.3ms
# Speed: 2.2ms preprocess, 73.3ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 83.7ms
# Speed: 1.0ms preprocess, 83.7ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 (no detections), 91.4ms
# Speed: 1.0ms preprocess, 91.4ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)
#
# 0: 160x256 1 metal, 89.9ms
# Bounding box coordinates --> 968.73926 1.2485504 1169.1318 584.52423
# Confidence ---> 0.33
# Class name --> Glass
# Speed: 1.0ms preprocess, 89.9ms inference, 1.0ms postprocess per image at shape (1, 3, 160, 256)

# %%
# !pip install ultralytics --upgrade
from IPython import display
display.clear_output()

import ultralytics
from ultralytics import YOLO
ultralytics.checks()
# Out:
# Ultralytics 8.3.55  Python-3.12.8 torch-2.5.1+cpu CPU (AMD Ryzen 7 7735U with Radeon Graphics)
# Setup complete  (16 CPUs, 13.7 GB RAM, 375.4/395.0 GB disk)

# %%
from ultralytics import YOLO

# Load a COCO-pretrained YOLO11n model
model = YOLO("yolo11m.pt")

# %%
from ultralytics import YOLO
import cv2
import math
import os
import numpy as np

# Start webcam
cap = cv2.VideoCapture(0)
cap.set(3, 1280)
cap.set(4, 720)

# Load model
# PATH = os.path.join(os.getcwd(), "colab notebook yolov8", "best.pt")
# PATH = os.path.join(os.getcwd(),  "colab notebook yolov11", "runs", "detect", "train", "weights", "best.pt")
PATH = "yolo11m.pt"
print(PATH)

model = YOLO(PATH)

# Object classes
classNames = ["cardboard", "glass", "metal", "paper", "plastic", "trash"]

while True:
    success, img = cap.read()
    if not success:
        break

    results = model(img, stream=True)

    # Process results
    for r in results:
        boxes = r.boxes

        for box in boxes:
            if box is None:
                continue
            # Bounding box coordinates
            x1, y1, x2, y2 = box.xyxy[0].numpy()
            print("Bounding box coordinates -->", x1, y1, x2, y2)
            if any(map(np.isnan, [x1, y1, x2, y2])):  # Check for NaN values
                print("Invalid bounding box coordinates detected.")
                continue  # Skip this box
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2)  # Convert to int values

            # Draw bounding box on image
            cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 3)

            # Confidence
            confidence = box.conf[0].cpu().numpy()
            confidence = math.ceil((confidence * 100)) / 100
            print("Confidence --->", confidence)

            # Class name
            cls = int(box.cls[0].cpu().numpy())
            print("Class name -->", cls)
            # print("Class name -->", classNames[cls])

            # Object details
            org = (x1, y1)
            font = cv2.FONT_HERSHEY_SIMPLEX
            fontScale = 1
            color = (255, 0, 0)
            thickness = 2

            cv2.putText(img, f"{cls} {confidence}", org, font, fontScale, color, thickness)

    cv2.imshow('Webcam', img)
    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
